# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("taylor_discography.csv")
df
# Out:
#                                track_name                track_id  \
# 0           Fortnight (feat. Post Malone)  6dODwocEuGzHAavXqTbwHv
# 1           The Tortured Poets Department  4PdLaGZubp4lghChqp8erB
# 2    My Boy Only Breaks His Favorite Toys  7uGYWMwRy24dm7RUDDhUlD
# 3                                Down Bad  1kbEbBdEgQdQeLXCJh28pJ
# 4                         So Long, London  7wAkQFShJ27V8362MqevQr
# ..                                    ...                     ...
# 429                        Wildest Dreams  59HjlYCeBsxdI0fcm3zglw
# 430                  How You Get The Girl  4dYUOfmWna6DFccnz732n8
# 431                             This Love  3oKMl2tJv4fdidkXUYMI5x
# 432                         I Know Places  3jBMHD19RZdAqG9iFQh7xc
# 433                                 Clean  06WgOCf0LV2h4keYXDRnuh
#
#      duration_ms  explicit  track_number                album_id  \
# 0         228965     False             1  5H7ixXZfsNMGbIE5OBSpcb
# ...

# %%
# removendo valores nulos
df = df.dropna()
df
# Out:
#                                track_name                track_id  \
# 0           Fortnight (feat. Post Malone)  6dODwocEuGzHAavXqTbwHv
# 1           The Tortured Poets Department  4PdLaGZubp4lghChqp8erB
# 2    My Boy Only Breaks His Favorite Toys  7uGYWMwRy24dm7RUDDhUlD
# 3                                Down Bad  1kbEbBdEgQdQeLXCJh28pJ
# 4                         So Long, London  7wAkQFShJ27V8362MqevQr
# ..                                    ...                     ...
# 429                        Wildest Dreams  59HjlYCeBsxdI0fcm3zglw
# 430                  How You Get The Girl  4dYUOfmWna6DFccnz732n8
# 431                             This Love  3oKMl2tJv4fdidkXUYMI5x
# 432                         I Know Places  3jBMHD19RZdAqG9iFQh7xc
# 433                                 Clean  06WgOCf0LV2h4keYXDRnuh
#
#      duration_ms  explicit  track_number                album_id  \
# 0         228965     False             1  5H7ixXZfsNMGbIE5OBSpcb
# ...

# %%
# Calculando a porcentagem de músicas em cada álbum
percentages_albuns = (album_track_counts / album_track_counts.sum()) * 100

# Plotando o gráfico de pizza
plt.figure(figsize=(12, 8))
plt.pie(percentages_albuns, labels=percentages.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Distribuição Percentual de Músicas por Álbum')
plt.axis('equal') 
plt.savefig('porcentagem_album.png')
plt.show()

# %%
# iniciando a analise de duração do album por minutos

#criando variáveis para posteriormente usar nos graficos
duration_min = df['duration_min'] 
albun_name = df['album_name']

df['duration_min'] = df['duration_ms'] / 60000 
album_duration = df.groupby('album_name')['duration_min'].sum().sort_values(ascending=False)
print(album_duration)

# gráfico de barras horizontal
plt.figure(figsize=(15, 8))
plt.barh(album_duration.index, album_duration.values, color='lightblue')
plt.xlabel('Duração em minutos')
plt.ylabel('Nome do Álbum')
plt.title('Duração do Álbum em minutos')
plt.savefig('grafico_duração-album.png')
plt.show()
# Out:
# album_name
# reputation Stadium Tour Surprise Song Playlist                                         186.266467
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]    134.704517
# Red (Taylor's Version)                                                                 130.663833
# THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY                                           122.645733
# Fearless (Taylor's Version)                                                            106.541500
# Speak Now (Taylor's Version)                                                           104.734183
# 1989 (Taylor's Version) [Deluxe]                                                        81.301667
# Midnights (The Til Dawn Edition)                                                        80.586083
# 1989 (Taylor's Version)                                                                 77.972117
# ...

# %%
# Grafico para realizar a análise de duração das músicas
df['duration_min'] = df['duration_ms'] / 60000
plt.figure(figsize=(10, 6))
sns.histplot(df['duration_min'], bins=30, kde=True)
plt.title('Distribuição da Duração das Músicas (em minutos)')
plt.xlabel('Duração (min)')
plt.ylabel('Contagem')
plt.savefig('grafico_duração-msc.png')
plt.show()

# %%
# Proporção de músicas explícitas por álbum
explicit_count = df.groupby('album_name')['explicit'].mean() * 100
print(explicit_count)
plt.figure(figsize=(12, 8))
explicit_count.sort_values().plot(kind='barh')
plt.title('Músicas Explícitas por Álbum (em %)')
plt.xlabel('Proporção (%)')
plt.ylabel('Álbum')
plt.savefig('musicas_expl.png')
plt.show()
# Out:
# album_name
# 1989                                                                                    0.000000
# 1989 (Deluxe Edition)                                                                   0.000000
# 1989 (Taylor's Version)                                                                 0.000000
# 1989 (Taylor's Version) [Deluxe]                                                        0.000000
# Fearless (Taylor's Version)                                                             0.000000
# Lover                                                                                   0.000000
# Midnights                                                                              46.153846
# Midnights (3am Edition)                                                                30.000000
# Midnights (The Til Dawn Edition)                                                       39.130435
# ...

# %%
# Calculando a duração das músicas por álbum em minutos
df['duration_min'] = df['duration_ms'] / 60000 
album_tempo = df.groupby('album_name')['duration_min'].sum().sort_values(ascending=False)
album_tempo_mean = df.groupby('album_name')['duration_min'].mean().sort_values(ascending=False)

# gráfico de barras horizontal para duração total
plt.figure(figsize=(15, 10))
plt.barh(album_duration_total.index, album_duration_total.values, color='lightblue')
plt.xlabel('Duração Total em minutos')
plt.ylabel('Nome do Álbum')
plt.title('Duração Total das Músicas por Álbum')
plt.savefig('media_tempo01.png')
plt.show()

# %%
# Segundo gráfico de barras horizontal para duração média
plt.figure(figsize=(15, 10))
plt.barh(album_duration_mean.index, album_duration_mean.values, color='lightgreen')
plt.xlabel('Duração Média em minutos')
plt.ylabel('Nome do Álbum')
plt.title('Duração Média das Músicas por Álbum')
plt.savefig('media_tempo02.png')
plt.show()
